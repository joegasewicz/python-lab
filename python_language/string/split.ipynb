# %%
# split() method

name = b'GET / HTTP/1.1\r\nHost: localhost:8000\r\nConnection: keep-alive\r\nCache-Control: max-age=0\r\nsec-ch-ua: "Brave";v="149"'
# Split all matching segments into a list
all_segment = name.split(b"\r\n", 1)

#  Only return the first segment of the string in index 1
#  & index 2 is the rest of string.
first_segment, tail_segment = name.split(b"\r\n", 1)

first_segment

tail_segment
# Out:
# b'Host: localhost:8000\r\nConnection: keep-alive\r\nCache-Control: max-age=0\r\nsec-ch-ua: "Brave";v="149"'
